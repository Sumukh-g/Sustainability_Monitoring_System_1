# %% [markdown]
# # 03 Forecasting Models
# Uses reusable production modules; outputs are calculated, not embedded.

# %%
from src.data_loader import load_data
from src.forecasting import train_models
comparison, metadata = train_models(load_data())
display(comparison)
metadata
