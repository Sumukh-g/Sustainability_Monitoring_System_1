# %% [markdown]
# # 05 Model Evaluation
# Uses reusable production modules; outputs are calculated, not embedded.

# %%
import pandas as pd
from src.evaluation import create_research_figures
display(pd.read_csv("../reports/evaluation/model_comparison.csv"))
create_research_figures()
